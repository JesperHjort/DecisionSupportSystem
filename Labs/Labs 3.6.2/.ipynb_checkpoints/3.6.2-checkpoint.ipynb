# %% [markdown]
# # 3.6.2 Simple Linear Regression
# ## Import and load data

# %%
from scipy import stats
import pandas as pd
import seaborn as sns
import scipy as sp
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from sklearn.preprocessing import scale
import sklearn.linear_model as skl_lm
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline
plt.style.use('seaborn-white')


boston = pd.read_csv('Data/Boston.csv')
boston[0:10]
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %% [markdown]
# A section of the 506 data points for each coloumn

# %% [markdown]
# # Linear Regression

# %%
regplot = sns.regplot(boston.lstat, boston.medv, order=1, ci=None, scatter_kws={'color':'r'})
regplot.set(xlabel='Percent of households with low socioeconomic status', ylabel='Median house value')
plt.xlim(xmin=0);

# %% [markdown]
# $$\hat{y} = \hat{\beta_0} + \hat{\beta_1} \cdot x$$

# %%
regr = skl_lm.LinearRegression()
X = boston.lstat.reshape(-1,1)
Y = boston.medv

regr.fit(X,Y)
print("Intercept: %f" % regr.intercept_)
print("Coefficient: %f" % regr.coef_)
# Out:
# Intercept: 34.553841
# Coefficient: -0.950049

# %% [markdown]
# ### See if equation gives same linear line

# %%
x = np.linspace(0,40)
y = regr.intercept_+regr.coef_*x
c = plt.plot(x,y)
plt.ylim(-10,60);
plt.xlabel('Percent of households with low socioeconomic status')
plt.ylabel('Median house value')

plt.legend([r'$\hat{medv} = \hat{\beta_0} + \hat{\beta_1} \cdot lstat$']);

# %%
res = smf.ols('medv ~ lstat', boston).fit()
res.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Residualer

# %%
print("Min: %f" % min(res.resid))
print("Median: %f" % np.median(res.resid))
print("Max: %f" % max(res.resid))
# Out:
# Min: -15.167452
# Median: -1.318186
# Max: 24.500129

# %%
res.conf_int()
# Out:
#                    0          1
# Intercept  33.448457  35.659225
# lstat      -1.026148  -0.873951

# %%
print("Residual degrees of freedom: %f" % res.df_resid)
# Out:
# Degrees of freedom: 504.000000

# %%
regr.predict(X)
boston['pred'] = regr.predict(X)
boston['resid'] = Y - boston.pred

ax1 = sns.regplot(boston.pred, boston.resid, lowess=True, 
line_kws={'color':'r', 'lw':2})
ax1.hlines(0,xmin=ax1.xaxis.get_data_interval()[0],
           xmax=ax1.xaxis.get_data_interval()[1], linestyles='dotted')
ax1.set_title('Residual Plot for Linear Fit');
ax1.set_xlabel('Fitted values');
ax1.set_ylabel('Residuals');

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(res, ax=ax, criterion="cooks", size=10)
plt.xlim(0,0.03);

# %%
new = pd.DataFrame([[1, 5], [1, 10], [1, 15]], columns=['Intercept', 'lstat'])

# %%
def predict(res, new):
    
    # Get the predicted values
    fit = pd.DataFrame(res.predict(new), columns=['fit'])
    
    # Get the confidence interval for the model (and rename the columns to something a bit more useful)
    ci = res.conf_int().rename(columns={0: 'lower', 1: 'upper'})
    
    # Now a little bit of matrix multiplication to get the confidence intervals for the predictions
    ci = ci.T.dot(new.T).T
    
    # And finally wrap up the confidence intervals with the predicted values
    return pd.concat([fit, ci], axis=1)


# In[112]:

predict(res, new)
# Out:
#          fit      lower      upper
# 0  29.803594  28.317716  31.289472
# 1  25.053347  23.186975  26.919720
# 2  20.303101  18.056234  22.549967
